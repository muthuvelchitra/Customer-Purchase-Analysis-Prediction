# %% [markdown]
# <a href="https://colab.research.google.com/github/muthuvelchitra/Customer-Purchase-Analysis-Prediction/blob/main/genAIpybasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.**variable**-Variable is the container it stores all data such as int,flot,charecter.

# %%
a=5
b=12
c=a+b
print(c)
# Out:
# 17

# %% [markdown]
# 2.**string**
#     -when a charecter nunber put a dobule quatation(" ")

# %%
a="15"
b="2"
c=a+b
print(c)
# Out:
# 152

# %% [markdown]
# 3.**input(runtime)**

# %%
a=int(input("Enter a: "))
b=int(input("Enter b: "))
c=a*b
print("The output is",c)
# Out:
# Enter a: 30
# Enter b: 20
# The output is 600

# %% [markdown]
# 4.**satement**

# %%
a=int(input("Enter a: "))
b= int(input("Enter b: "))
c= int(input ("Enter c: "))
if a>b and a>c:
  print("A is larger")
elif b>a and b>c:
  print("B is larger")
else:
  print("C is larger")
# Out:
# Enter a: 40
# Enter b: 90
# Enter c: 12
# B is larger

# %% [markdown]
# **boolean operators**
#
# > and=> if both are true
# > or=> if any one true

# %% [markdown]
# 5.**For loop**(tables)
#
# > syntax =>for i in range(start,end,[step]):

# %%
for i in range(1,16):
  print(i,"X5=",i*5)
# Out:
# 1 X5= 5
# 2 X5= 10
# 3 X5= 15
# 4 X5= 20
# 5 X5= 25
# 6 X5= 30
# 7 X5= 35
# 8 X5= 40
# 9 X5= 45
# 10 X5= 50
# 11 X5= 55
# 12 X5= 60
# 13 X5= 65
# 14 X5= 70
# 15 X5= 75

# %% [markdown]
# 6.**List**
#
# >
#
# 1.   mutable
# 2.   square bracket
# 1.   can use any data type

# %%
l=[1,2,"raja",3,4]
print(l)
# Out:
# [1, 2, 'raja', 3, 4]

# %%
fruit=["APPLE","ORANGE","MANGO"]
print(fruit[0])
print(fruit[2])
print(fruit)
# Out:
# APPLE
# MANGO
# ['APPLE', 'ORANGE', 'MANGO']

# %% [markdown]
# > append()

# %%
a=[1,3,4,7]
print(a)
a.append(8)
print(a)
# Out:
# [1, 3, 4, 7]
# [1, 3, 4, 7, 8]

# %% [markdown]
# > pop()

# %%
a=[1,3,4,7,6]
print(a)
a.pop(3)
print(a)
# Out:
# [1, 3, 4, 7, 6]
# [1, 3, 4, 6]

# %% [markdown]
# 7.**Dictionary**

# %%
a={"name":"chitra",
"age":20}
print(a)
# Out:
# {'name': 'chitra', 'age': 20}
